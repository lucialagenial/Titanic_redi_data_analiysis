# %% [markdown]
# <a href="https://colab.research.google.com/github/lucialagenial/Titanic_redi_data_analiysis/blob/main/Lucia_Copia_de_Python_Midterm_Test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![titanic.jpg](https://image.geo.de/31780898/t/gt/v3/w960/r1.5/-/titanic---pa--122855442.jpg)
# # Midterm Test
#
# Hello!
#
# You already learned a lot how to explore and understand data. Let's test this! If you hand in your solution we will check it so you get direct feedback and know where you stand. To get feedback save a copy and rename it, so it contains your name. Then save the copy to this
# [folder](https://drive.google.com/drive/folders/1JqOTlRt9VhK3NVHt0svBHLI8DnMdpp5Q?usp=sharing).
#
# The deadline for handing in your solution is May 9.
#
# You can answer those questions as you wish by just coding or inspecting the data through a plot. But please answer the question with a sentence or two where you explain what the result is telling you.
#
# If you have any questions, please ask us on slack. We are happy to help.
#
# Have fun coding!
#
# ### Titanic Dataset
#
# Today we will explore a new dataset, the infamous Titanic dataset. It contains informations on passengers of the Titanic. At kaggle many people already investigated this dataset. Check it out to get new ideas: -> https://www.kaggle.com/c/titanic/overview
#
#
# The dataset contains 12 columns.
#
# - survival: 	Survival 	0 = No, 1 = Yes
# - pclass: 	Ticket class 	1 = 1st, 2 = 2nd, 3 = 3rd
# - sex: 	Sex
# - Age: 	Age in years
# - sibsp: 	# of siblings / spouses aboard the Titanic
# - parch: 	# of parents / children aboard the Titanic
# - ticket: 	Ticket number
# - fare: 	Passenger fare
# - cabin: 	Cabin number
# - embarked: 	Port of Embarkation 	C = Cherbourg, Q = Queenstown, S = Southampton
#
# It can be downloaded from: https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

# %% [markdown]
# ### 1. Load Libraries and data
#
# Load libraries you might need and load the data using pandas. Get a first overview:
# - Is the data loaded correctly?
# - How does it look like?
# - How many rows, how many columns?
# - Do we see any Null values? What could they mean?

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# this is a hack to allow displaying more than one result per notebook cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Is the data loaded correctly? - Yes 
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# How does it look like?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# How many rows, how many columns? 
df.shape
# Out:
# (891, 12)

# %%
# Nice way of checking the percentages of null values for each column
# You could also add a small interpretation of what it means that the 2nd/3rd class passengers
# didn't have a cabin assigned. Probably a cabin was expensive, so only 1st class
# passengers could afford it. 2nd/3rd class passengers probably shared common rooms. 

# Do we see any Null values? What could they mean?
(df.isnull().sum() / len(df)).sort_values(ascending = False)
# Most of second and third class passengers did not have a cabin number assigned.
# Out:
# Cabin          0.771044
# Age            0.198653
# Embarked       0.002245
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# dtype: float64

# %%
df.Pclass.value_counts().sort_values(ascending = True)
# Out:
# 2    184
# 1    216
# 3    491
# Name: Pclass, dtype: int64

# %%
df.Cabin.isnull().sum()
# Out:
# 687

# %%
# nice use of "reset_index"
df.groupby(['Pclass'])['Cabin'].count().reset_index()
# Out:
#    Pclass  Cabin
# 0       1    176
# 1       2     16
# 2       3     12

# %% [markdown]
# ### 2. What is the average fare per class? On which range do the fares per class spread?

# %%
# Average fare per class: 
df.groupby(['Pclass'])[['Fare']].mean().reset_index()
# Out:
#    Pclass       Fare
# 0       1  84.154687
# 1       2  20.662183
# 2       3  13.675550

# %%
# To get an idea of the distribution you can also look into some plots that can visualize it nicely. 
# For example, you can do a boxplot to show how the prices spread for the different classes:
# sns.boxplot(data=df, y="Fare", x="Pclass")

max_pclass_fare = df.groupby(['Pclass'])[['Fare']].max().round(1).reset_index()
max_pclass_fare.rename(columns={'Pclass':'Pclass', 'Fare':'Max Fare'}, inplace =True)
min_pclass_fare = df.groupby(['Pclass'])[['Fare']].min().round(1).reset_index()
min_pclass_fare.rename(columns= {'Pclass':'Remove', 'Fare':'Min Fare'}, inplace = True)
max_min_pclass_fare = pd.concat([max_pclass_fare, min_pclass_fare], axis=1)

max_min_pclass_fare.drop(columns = 'Remove', axis=1, inplace=True)
max_min_pclass_fare
max_min_pclass_fare['Range'] = (max_min_pclass_fare['Max Fare'] - max_min_pclass_fare['Min Fare'])
max_min_pclass_fare

sns.boxplot(data=df, y="Fare", x="Pclass")
# Out:
#    Pclass  Max Fare  Min Fare
# 0       1     512.3       0.0
# 1       2      73.5       0.0
# 2       3      69.6       0.0
#    Pclass  Max Fare  Min Fare  Range
# 0       1     512.3       0.0  512.3
# 1       2      73.5       0.0   73.5
# 2       3      69.6       0.0   69.6

# %% [markdown]
# ### 3. How many people had a cabin?

# %%
# One general comment, but it’s more about style
# I would always use df['column'] to access a column, instead of df.column. 
# The 2nd one can be misleading because it's the same syntax that you use to
# call a method on the dataframe object.

# %%
# This is correct. pandas also provides a nice "notnull" helper method. So 
# an alternative solution could be: df['Cabin'].notnull().sum()
(len(df.Cabin))- (df.Cabin.isnull().sum())
# Out:
# 204

# %%
df['Cabin'].notnull().sum()
# Out:
# 204

# %%
# good naming of variables
pp_with_Cabin = (len(df.Cabin))- (df.Cabin.isnull().sum())
pp_withno_Cabin = df.Cabin.isnull().sum()

colors = sns.color_palette('pastel')[0:5]

# nice visualization
plt.pie([pp_with_Cabin, pp_withno_Cabin], labels = ['Cabin assigned', 'No cabin'], colors = colors, autopct='%.0f%%')
plt.title("Cabin Allocation")
plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8756359e90>,
# ...
#  [Text(0.8275031118894708, 0.7247334681199993, 'Cabin assigned'),
#   Text(-0.8275031118894708, -0.7247334681199994, 'No cabin')],
#  [Text(0.4513653337578931, 0.3953091644290905, '23%'),
#   Text(-0.4513653337578931, -0.39530916442909053, '77%')])
# Text(0.5, 1.0, 'Cabin Allocation')

# %% [markdown]
# ### 4. At which port lived the richest?

# %%
# That gives a good overview. But you can run into problems if you for example have
# many 2nd/3rd class passengers that embark from a port and few, but rich, 1st class passengers.
# This might skew the results. So to get a bit more details you could do a query like this:
# df.groupby(["Embarked", "Pclass"])[["Fare"]].agg(['count', 'mean'])
# This shows you how many people embarked from a given port per class and the avg. prices for the groups.
# Cherbourg still seems to be the richest place. It's the place with the highest avg. prices for
# 1st class tickets and the highest proportion of 1st class passengers.
embarked_fare = df.groupby(['Embarked'])[['Fare']].mean().round(2).reset_index()
embarked_fare
sns.barplot(x = embarked_fare.Embarked,y = embarked_fare.Fare )
# C = Cherbourg
# Out:
#   Embarked   Fare
# 0        C  59.95
# 1        Q  13.28
# 2        S  27.08

# %%
 df.groupby(["Embarked", "Pclass"])[["Fare"]].agg(['count', 'mean']).reset_index()
# Out:
#   Embarked Pclass  Fare
#                   count        mean
# 0        C      1    85  104.718529
# 1        C      2    17   25.358335
# 2        C      3    66   11.214083
# 3        Q      1     2   90.000000
# 4        Q      2     3   12.350000
# 5        Q      3    72   11.183393
# 6        S      1   127   70.364862
# 7        S      2   164   20.327439
# 8        S      3   353   14.644083

# %% [markdown]
# ### 5. What is the most frequent last name?

# %%
# This option does not seem to work
df['Name'].value_counts().idxmax()
# Out:
# 'Braund, Mr. Owen Harris'

# %%
# That's a very nice solution. 
# I like the helper function, clean overall code, creativity in the use of additional libraries.
# 
# It's only slightly off for the question at hand, but that's not that important,
# because the approach goes in the right direction and can be adjusted easily.
# In the previous cell you mention that a simple "value_counts" on Name doesn't work.
# In fact, the "Name" column contains the whole name of a passenger in the format
# LAST NAME, FIRST NAME
# In your solution you're extracting every part of the name, so also the first and
# middle name(s). So you're counting all those parts of a name and it is difficult
# to see which results are actually last names and which are not. 
# A simplified approach could be to just split the name by "," and extract the first element
# (which represents the last name)
# df["last_name"] = df["Name"].apply(lambda name: name.split(",")[0])
# df["last_name"].value_counts().sort_values(ascending=False)
# Note that your helper function for the string processing looks more robust. So 
# I would keep some parts of it

import nltk
import re
import string
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize

stop_words = stopwords.words()

def cleaning(text):        
    # converting to lowercase, removing Mr & Miss etc
    text = re.sub('()', '', text)
    text = re.sub('Mr', '', text)
    text = re.sub('Miss', '', text)
    text = re.sub('Mrs', '', text)
    text = re.sub('Master', '', text)
    text = re.sub('Dr', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
 

    # removing the stop-words          
    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word in stop_words]
    name.split(",")
    filtered_sentence = (" ").join(tokens_without_sw)
    text = filtered_sentence
    
    return text
# Two new lines added
# df["last_name"] = dt["Name"].apply(lambda name: name.split(",")[0])
# dt["last_name"].value_counts().sort_values(ascending=False)
# Until here
dt = df['Name'].apply(cleaning)

from collections import Counter
p = Counter(" ".join(dt).split()).most_common(42)
rslt = pd.DataFrame(p, columns=['Word', 'Frequency'])
print(rslt)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
#          Word  Frequency
# 0     William         64
# 1        John         44
# 2       Henry         35
# 3       James         24
# 4      George         24
# 5     Charles         23
# 6      Thomas         22
# 7        Mary         20
# 8      Edward         18
# 9        Anna         17
# 10     Joseph         16
# 11  Elizabeth         15
# 12      Johan         15
# 13  Frederick         15
# 14    Richard         14
# 15     Samuel         13
# 16     Arthur         13
# 17   Margaret         12
# 18     Alfred         12
# 19      Maria         11
# 20  Alexander         11
# 21      Peter         11
# 22     Robert         10
# 23         Jr         10
# 24    Leonard          9
# 25  Andersson          9
# ...

# %%
# Johnson seems to be the most frequent last name 
for row in dt:
  if 'Johnson' in row:
    print(row)
# Out:
# Johnson Oscar W Elisabeth Vilhelmina Berg
# Johnson Eleanor Ileen
# Johnson William Cahoone Jr
# Johnson Alfred
# Johnson Malkolm Joackim
# Johnson Harold Theodor

# %%
# Easiest solution 
df["last_name"] = df["Name"].apply(lambda name: name.split(",")[0])
df["last_name"].value_counts().sort_values(ascending=False)
# Out:
# Andersson        9
# Sage             7
# Panula           6
# Skoog            6
# Carter           6
#                 ..
# Abbing           1
# Culumovic        1
# Lemberopolous    1
# Serepeca         1
# Dooley           1
# Name: last_name, Length: 667, dtype: int64

# %%
for row in dt:
  if 'Andersson' in row:
    print(row)
# Out:
# Andersson Anders Johan
# Andersson Erna Alexandra
# Andersson Ellis Anna Maria
# Andersson August Edvard Wennerstrom
# Andersson Ingeborg Constanzia
# Andersson Sigrid Elisabeth
# Andersson Anders Johan Alfrida Konstantia Brogren
# Andersson Ebba Iris Alfrida
# Andersson Sigvard Harald Elias

# %% [markdown]
# ### 6. Not for every person the age is noted. Fill in the gaps with the average age per gender.

# %%
# That's a very nice solution! I didn't know about this transform option
df['Age'] = df['Age'].fillna(df.groupby('Sex')['Age'].transform('mean'))
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# ...

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Bonus: Upload this file as .ipnyb - notebook in your personal git-hub account and share the address here.

# %%
# address: https://github.com/lucialagenial/Titanic_redi_data_analiysis.git
